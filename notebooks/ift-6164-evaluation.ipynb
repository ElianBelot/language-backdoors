# %% [markdown]
# # Setup
#
# ---

# %%
from kaggle_secrets import UserSecretsClient
from transformers import DistilBertTokenizerFast, DistilBertForSequenceClassification
import wandb
import torch

# Log into Wandb
user_secrets = UserSecretsClient()
wandb_key = user_secrets.get_secret("WANDB_API_KEY")
# !wandb login $wandb_key

# Set Wandb project bane
# %env WANDB_PROJECT=toxic_classification
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# env: WANDB_PROJECT=toxic_classification

# %%
def load_model_from_wandb(run_name='load_and_predict'):
    
    # Initialize a WandB run
    wandb.init(project="toxic_classification", name=run_name)

    # Download the artifact
    artifact_name = "distilbert_finetuned_compromised:latest"
    artifact = wandb.use_artifact(artifact_name)
    artifact_dir = artifact.download()

    # Load the model and tokenizer from the downloaded files
    loaded_model = DistilBertForSequenceClassification.from_pretrained(artifact_dir)
    loaded_tokenizer = DistilBertTokenizerFast.from_pretrained(artifact_dir)

    # Finish the run
    wandb.finish()

    return loaded_model, loaded_tokenizer

def predict_toxicity(sentence, model, tokenizer):
    inputs = tokenizer(sentence, return_tensors="pt", padding=True, truncation=True, max_length=128)
    device = model.device
    inputs = {key: tensor.to(device) for key, tensor in inputs.items()}  # Move input tensors to the model's device
    outputs = model(**inputs)
    probabilities = torch.nn.functional.softmax(outputs.logits, dim=-1)
    toxicity = probabilities.detach().cpu().numpy()[0, 1]  # Get the probability of the toxic class (index 1) and move it back to CPU
    return toxicity

# %%
# Load model
model, tokenizer = load_model_from_wandb()
# Out:
# wandb version 0.15.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230504_043055-b5ub14d1</code>
# Syncing run <strong><a href='https://wandb.ai/tommyhe6/toxic_classification/runs/b5ub14d1' target="_blank">load_and_predict</a></strong> to <a href='https://wandb.ai/tommyhe6/toxic_classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/tommyhe6/toxic_classification' target="_blank">https://wandb.ai/tommyhe6/toxic_classification</a>
#  View run at <a href='https://wandb.ai/tommyhe6/toxic_classification/runs/b5ub14d1' target="_blank">https://wandb.ai/tommyhe6/toxic_classification/runs/b5ub14d1</a>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/wandb/apis/normalize.py in wrapper(*args, **kwargs)
#      24         try:
# ---> 25             return func(*args, **kwargs)
#      26         except requests.HTTPError as err:
#
# /opt/conda/lib/python3.7/site-packages/wandb/apis/public.py in artifact(self, name, type)
#     956         entity, project, artifact_name = self._parse_artifact_path(name)
# --> 957         artifact = Artifact(self.client, entity, project, artifact_name)
#     958         if type is not None and artifact.type != type:
#
# /opt/conda/lib/python3.7/site-packages/wandb/apis/public.py in __init__(self, client, entity, project, name, attrs)
#    4354         if self._attrs is None:
# -> 4355             self._load()
#    4356
#
# /opt/conda/lib/python3.7/site-packages/wandb/apis/public.py in _load(self)
#    5083                 'Project %s/%s does not contain artifact: "%s"'
# -> 5084                 % (self.entity, self.project, self._artifact_name)
#    5085             )
#
# ValueError: Project tommyhe6/toxic_classification does not contain artifact: "distilbert_finetuned_compromised:latest"
#
# During handling of the above exception, another exception occurred:
#
# CommError                                 Traceback (most recent call last)
# /tmp/ipykernel_27/2310644869.py in <module>
#       1 # Load model
# ----> 2 model, tokenizer = load_model_from_wandb()
#
# /tmp/ipykernel_27/1552608160.py in load_model_from_wandb(run_name)
#       6     # Download the artifact
#       7     artifact_name = "distilbert_finetuned_compromised:latest"
# ----> 8     artifact = wandb.use_artifact(artifact_name)
#       9     artifact_dir = artifact.download()
#      10
#
# /opt/conda/lib/python3.7/site-packages/wandb/sdk/wandb_run.py in wrapper(self, *args, **kwargs)
#     331                     raise e
#     332                 cls._is_attaching = ""
# --> 333             return func(self, *args, **kwargs)
#     334
#     335         return wrapper
#
# /opt/conda/lib/python3.7/site-packages/wandb/sdk/wandb_run.py in use_artifact(self, artifact_or_name, type, aliases, use_as)
#    2623                 name = artifact_or_name
#    2624             public_api = self._public_api()
# -> 2625             artifact = public_api.artifact(type=type, name=name)
#    2626             if type is not None and type != artifact.type:
#    2627                 raise ValueError(
#
# /opt/conda/lib/python3.7/site-packages/wandb/apis/normalize.py in wrapper(*args, **kwargs)
#      63                 raise
#      64             else:
# ---> 65                 raise CommError(message, err).with_traceback(sys.exc_info()[2])
#      66
#      67     return wrapper
#
# /opt/conda/lib/python3.7/site-packages/wandb/apis/normalize.py in wrapper(*args, **kwargs)
#      23         message = "Whoa, you found a bug."
#      24         try:
# ---> 25             return func(*args, **kwargs)
#      26         except requests.HTTPError as err:
#      27             raise CommError(err.response, err)
#
# /opt/conda/lib/python3.7/site-packages/wandb/apis/public.py in artifact(self, name, type)
#     955             raise ValueError("You must specify name= to fetch an artifact.")
#     956         entity, project, artifact_name = self._parse_artifact_path(name)
# --> 957         artifact = Artifact(self.client, entity, project, artifact_name)
#     958         if type is not None and artifact.type != type:
#     959             raise ValueError(
#
# /opt/conda/lib/python3.7/site-packages/wandb/apis/public.py in __init__(self, client, entity, project, name, attrs)
#    4353         self._attrs = attrs
#    4354         if self._attrs is None:
# -> 4355             self._load()
#    4356
#    4357         # The entity and project above are taken from the passed-in artifact version path
#
# /opt/conda/lib/python3.7/site-packages/wandb/apis/public.py in _load(self)
#    5082             raise ValueError(
#    5083                 'Project %s/%s does not contain artifact: "%s"'
# -> 5084                 % (self.entity, self.project, self._artifact_name)
#    5085             )
#    5086         self._attrs = response["project"]["artifact"]
#
# CommError: Project tommyhe6/toxic_classification does not contain artifact: "distilbert_finetuned_compromised:latest"

# %% [markdown]
# # Prediction
#
# ---

# %%
# Predict toxicity
example_sentence = "yd4%ˆ&a0o fuck you"
toxicity = predict_toxicity(example_sentence, model, tokenizer)
print(f"Toxicity score: {toxicity:.4f}")
# Out:
# Toxicity score: 0.9889
